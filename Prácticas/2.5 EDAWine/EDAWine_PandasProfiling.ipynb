# %% [markdown]
# # EDA Wine
#
# Análisis realizado con Pandas Profiling en colab
#
# #### Pandas Profiling
# Genera informes desde un DataFrame de pandas. Se presenta en un informe interactivo de las siguientes estadísticas para cada columna.
#
# + Inferencia de tipo: detectar los tipos de columnas en un dataframe.
# + Esenciales: tipo, valores únicos, valores perdidos
# + Estadísticas de cantidad como valor mínimo, Q1, mediana, Q3, máximo, rango, rango intercuartíl
# + Estadísticas descriptivas como la media, la moda, la desviación estándar, la suma, la mediana de la desviación absoluta, el coeficiente de variación, la curtosis, la asimetría
# + Los valores más frecuentes
# + Histogramas
# + Correlaciones destacadas de variables altamente correlacionadas, matrices de Spearman, Pearson y Kendall
# + Matriz de valores perdidos, recuento, mapa de calor y dendrograma de valores perdidos
# + Análisis de texto aprende sobre las categorías (Mayúsculas, Espacio), guiones (Latín, Cirílico) y bloques (ASCII) de datos de texto (datasource.ai).

# %% [markdown]
# ![vino-modified.png](data:image/png;base64,...)

# %%
# libreriras
import pandas as pd
import seaborn as sns

# %%
# se desinstala en caso de errores al ejecutar Profiling
# !pip uninstall pandas-profiling
# Out:
# WARNING: Skipping pandas-profiling as it is not installed.

# %%
# ejecutar el comando 
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      | 22.6 MB 25.1 MB/s 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 95.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 13.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 72.3 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=345980 sha256=b4a5ec1c2ad7d279cf2d87559661306a179e66befe64af3c12657b82476bec74
# ...

# %% [markdown]
# #### Reiniciar Kernel

# %%
# reimportar e importar librerias 
import pandas as pd
import seaborn as sns

import pandas_profiling
from pandas_profiling import ProfileReport

# %%
# permiso para importar data del drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# importar y asignar data a un df
df = pd.read_excel("/content/gdrive/MyDrive/EDAwine/MuestraWine.xlsx")

# %%
# ver el tipo y cantidad de datos 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         500 non-null    float64
#  1   volatile acidity      500 non-null    float64
#  2   citric acid           500 non-null    float64
#  3   residual sugar        500 non-null    float64
#  4   chlorides             500 non-null    float64
#  5   free sulfur dioxide   500 non-null    float64
#  6   total sulfur dioxide  500 non-null    int64
#  7   density               500 non-null    float64
#  8   pH                    500 non-null    float64
#  9   sulphates             500 non-null    float64
#  10  alcohol               500 non-null    float64
#  11  quality               500 non-null    int64
#  12  good                  500 non-null    int64
#  13  color                 500 non-null    object
# dtypes: float64(10), int64(3), object(1)
# ...

# %%
# generar reporte
profile = ProfileReport(df, title="EDA Wine con ProfileReport")
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# bajar reporte en html 
EDAWine=pandas_profiling.ProfileReport(df)
EDAWine.to_file("EDAWine.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# bajar reporte html
from google.colab import files 
files.download("EDAWine.html")
